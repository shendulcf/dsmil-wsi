# %% [markdown]
# 1. WSI 目录设置

# %%
# !python transfer.py

# %% [markdown]
# 2. 切分Patches

# %%
import os
import openslide
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

slide_dir = r'/home/sci/Disk2/tcga_brca/WSI/tcga_brca/1'
slide_list = os.listdir(slide_dir)
slide = openslide.OpenSlide(os.path.join(slide_dir,slide_list[0]))
slide.properties
slide.level_count
slide.level_dimensions
slide.level_downsamples
# Out:
# <_PropertyMap {'aperio.AppMag': '40', 'aperio.DSR ID': 'resc3-dsr2', 'aperio.Date': '06/10/11', 'aperio.DisplayColor': '0', 'aperio.Exposure Scale': '0.000001', 'aperio.Exposure Time': '109', 'aperio.Filename': 'TCGA-AC-A2FB-01A-01-TS1', 'aperio.Focus Offset': '-0.000500', 'aperio.ICC Profile': 'ScanScope v1', 'aperio.ImageID': '67937', 'aperio.Left': '15.835623', 'aperio.LineAreaXOffset': '0.006927', 'aperio.LineAreaYOffset': '-0.001649', 'aperio.LineCameraSkew': '-0.000950', 'aperio.MPP': '0.2468', 'aperio.OriginalHeight': '31955', 'aperio.OriginalWidth': '81344', 'aperio.Parmset': 'GOG136 on RESBPCLACIE01', 'aperio.ScanScope ID': 'SS1552CNTLR', 'aperio.StripeWidth': '992', 'aperio.Time': '07:46:49', 'aperio.Time Zone': 'GMT-04:00', 'aperio.Title': 'TCGA-AC-A2FB-01A-01-TS1', 'aperio.Top': '13.940570', 'aperio.User': 'faa57c9b-73c2-4480-b537-472fc24388cc', 'openslide.comment': 'Aperio Image Library v10.2.41\r\n81344x31955 [0,100 78064x31855] (240x240) JPEG/RGB Q=30|AppMag = 40|Strip
# ...

# %%
# !python deepzoom_tiler.py -m 0 2 -b 20 -d tcga_brca
# Out:
# Process slide 1/490
# Tiling slide: wrote 43400/54558 tiles
#  Organizing patches
#  Patch [257/257]Done.
# Process slide 2/490
# Tiling slide: wrote 29600/37202 tiles
#  Organizing patches
#  Patch [110/110]Done.
# Process slide 3/490
# Tiling slide: wrote 23100/116150 tiles
#  Organizing patches
#  Patch [369/369]Done.
# Process slide 4/490
# Tiling slide: wrote 15300/19300 tiles
#  Organizing patches
#  Patch [129/129]Done.
# Process slide 5/490
# Tiling slide: wrote 15900/19995 tiles
#  Organizing patches
#  Patch [204/204]Done.
# Process slide 6/490
# Tiling slide: wrote 10100/12727 tiles
#  Organizing patches
#  Patch [196/196]Done.
# Process slide 7/490
# Tiling slide: wrote 13000/16412 tiles
#  Organizing patches
#  Patch [144/144]Done.
# Process slide 8/490
# Tiling slide: wrote 27000/34046 tiles
#  Organizing patches
#  Patch [236/236]Done.
# Process slide 9/490
# Tiling slide: wrote 18700/23637 tiles
#  Organizing patches
#  Patch [311/311]Done.
# Process slide 10/490
# ...

# %%
# !cd simclr
# !python run.py # remember add --dataset
# Out:
# python: can't open file '/home/sci/PycharmProjects/chaofan/projects/dsmil-wsi/run.py': [Errno 2] No such file or directory

# %%
# !python compute_feats.py --magnification=tree --dataset=tcga_brca --weights_low=May07_20-35-17_sci-MS-7D42  --weights_high=May23_18-59-38_sci-MS-7D42
# Out:
# /home/sci/anaconda3/envs/lcf/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/sci/anaconda3/envs/lcf/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# Use pretrained features.
#  Computed: 1/490 -- 255/255
#
#  Computed: 2/490 -- 191/191
#
#  Computed: 3/490 -- 214/214
#
#  Computed: 4/490 -- 282/282
#
#  Computed: 5/490 -- 297/297
#
#  Computed: 6/490 -- 190/190
#
#  Computed: 7/490 -- 233/233
#
#  Computed: 8/490 -- 257/257
#
#  Computed: 9/490 -- 165/165
#
#  Computed: 10/490 -- 147/147
#
#  Computed: 11/490 -- 176/176
#
#  Computed: 12/490 -- 144/144
#
#  Computed: 13/490 -- 115/115
#
# ...

# %%
# !python train_tcga.py --dataset=tcga_brca #--num_epochs=100
# Out:
# /home/sci/PycharmProjects/chaofan/projects/dsmil-wsi/train_tcga.py:43: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   bag_label = Variable(Tensor([label]))
#  Epoch [1/100] train loss: 0.4395 test loss: 0.4834, average score: 0.7449, AUC: class-0>>0.8939759036144579|class-1>>0.9759036144578314
# Best model saved at: weights/05252023/1.pth
# Best thresholds ===>>> class-0>>0.057929228991270065|class-1>>0.9424282312393188
#  Epoch [2/100] train loss: 0.4323 test loss: 0.4357, average score: 0.8878, AUC: class-0>>0.9630522088353413|class-1>>0.9823293172690762
# Best model saved at: weights/05252023/1.pth
# Best thresholds ===>>> class-0>>0.2384776771068573|class-1>>0.7607451677322388
# ...

# %%
# !python attention_map.py --bag_path test/patches --map_path test/output --thres 0.73 0.28
# Out:
# test/patches/LUSC-TCGA-22-0940-01Z-00-DX1 is detected as: class 1
# test/patches/LUAD-TCGA-05-4417-01Z-00-DX1 is detected as: class 1
# test/patches/LUAD-TCGA-55-8087-01Z-00-DX1 is detected as: class 1
# test/patches/LUAD-TCGA-55-6986-01Z-00-DX1 is detected as: class 1
# test/patches/LUSC-TCGA-63-A5MB-01Z-00-DX1 is detected as: class 1
# test/patches/LUSC-TCGA-22-5474-01Z-00-DX1 is detected as: class 1
